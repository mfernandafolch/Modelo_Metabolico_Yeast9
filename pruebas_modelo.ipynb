# %% [markdown]
# # Revisión modelo metabólico Yeast9

# %%
import cobra
from cobra.io import read_sbml_model
import numpy as np
from scipy.integrate import solve_ivp
from matplotlib import pyplot as plt

# %%
# Cargamos el modelo metabólico:
model_original_o2 = read_sbml_model("yeast-GEM.xml")
model_original_sin_o2 = read_sbml_model("yeast9_anaerobic.xml")
model_modificado = read_sbml_model("yeast9_anaerobic.xml")

# %%
# Imprimir información básica del modelo
print("Componentes modelo Yeast9")
print("Reacciones:", len(model_original_o2.reactions))
print("Metabolitos:", len(model_original_o2.metabolites))
print("Genes:", len(model_original_o2.genes))

# Imprimir información básica del modelo
print("\nComponentes modelo Yeast9 anaeróbico")
print("Reacciones:", len(model_original_sin_o2.reactions))
print("Metabolitos:", len(model_original_sin_o2.metabolites))
print("Genes:", len(model_original_sin_o2.genes))
# Out:
# Componentes modelo Yeast9
# Reacciones: 4131
# Metabolitos: 2806
# Genes: 1161
#
# Componentes modelo Yeast9 anaeróbico
# Reacciones: 4131
# Metabolitos: 2806
# Genes: 1161

# %%
# Función objetivo del FBA
print(model_original_o2.objective)

with model_original_o2:
    model_original_o2.optimize()
    print("Flujo óptimo (FBA):", model_original_o2.objective.value)
    pfba_solution = cobra.flux_analysis.pfba(model_original_o2)
    print(f"Flujos de reacción (pFBA): {pfba_solution.objective_value}")
# Out:
# Maximize
# 1.0*r_2111 - 1.0*r_2111_reverse_58b69
# Flujo óptimo (FBA): 0.08584396972646902
# Flujos de reacción (pFBA): 100.06167152723609

# %% [markdown]
# ## Modelo original:

# %%
model_original_o2.reactions.get_by_id("r_2111")
# Out:
# <Reaction r_2111 at 0x243e8aa15a0>

# %%
# Límites superiores de importación de nutrientes
reacciones_medio = model_original_o2.medium

# %%
for rxn_id, limit in reacciones_medio.items():
   name = model_original_o2.reactions.get_by_id(rxn_id).name
   print(f"{rxn_id}: {name} (límite: {limit})")
# Out:
# r_1654: ammonium exchange (límite: 1000.0)
# r_1714: D-glucose exchange (límite: 1.0)
# r_1832: H+ exchange (límite: 1000.0)
# r_1861: iron(2+) exchange (límite: 1000.0)
# r_1992: oxygen exchange (límite: 1000.0)
# r_2005: phosphate exchange (límite: 1000.0)
# r_2020: potassium exchange (límite: 1000.0)
# r_2049: sodium exchange (límite: 1000.0)
# r_2060: sulphate exchange (límite: 1000.0)
# r_2100: water exchange (límite: 1000.0)
# r_4593: chloride exchange (límite: 1000.0)
# r_4594: Cu2(+) exchange (límite: 1000.0)
# r_4595: Mn(2+) exchange (límite: 1000.0)
# r_4596: Zn(2+) exchange (límite: 1000.0)
# r_4597: Mg(2+) exchange (límite: 1000.0)
# r_4600: Ca(2+) exchange (límite: 1000.0)

# %%
len(model_original_o2.exchanges)
# Out:
# 271

# %%
contador_exportaciones = 0
contador_importaciones = 0
for rxn in model_original_o2.exchanges:
    if rxn.lower_bound < 0:  # Solo reacciones de importación
        contador_importaciones += 1
        print(f"{rxn.id}: {rxn.name} (límite: {rxn.lower_bound})")
    if rxn.upper_bound > 0:  # Solo reacciones de exportación
        contador_exportaciones += 1
    else:
        print(f"REACCIÓN EXPORTACIÓN {rxn.id}: {rxn.name} (límite: {rxn.upper_bound})")
        
print(f"Total de reacciones de importación: {contador_importaciones}")
print(f"Total de reacciones de exportación: {contador_exportaciones}")
# Out:
# r_1654: ammonium exchange (límite: -1000.0)
# REACCIÓN EXPORTACIÓN r_1663: bicarbonate exchange (límite: 0.0)
# r_1714: D-glucose exchange (límite: -1.0)
# r_1832: H+ exchange (límite: -1000.0)
# r_1861: iron(2+) exchange (límite: -1000.0)
# r_1992: oxygen exchange (límite: -1000.0)
# r_2005: phosphate exchange (límite: -1000.0)
# r_2020: potassium exchange (límite: -1000.0)
# r_2049: sodium exchange (límite: -1000.0)
# r_2060: sulphate exchange (límite: -1000.0)
# r_2100: water exchange (límite: -1000.0)
# r_4593: chloride exchange (límite: -1000.0)
# r_4594: Cu2(+) exchange (límite: -1000.0)
# r_4595: Mn(2+) exchange (límite: -1000.0)
# r_4596: Zn(2+) exchange (límite: -1000.0)
# r_4597: Mg(2+) exchange (límite: -1000.0)
# r_4600: Ca(2+) exchange (límite: -1000.0)
# Total de reacciones de importación: 16
# Total de reacciones de exportación: 270

# %% [markdown]
# * Hay 16 reacciones de intercambio que tienen lower bounds abiertos (medio).
# * La única reacción de intercambio que tiene el upper bound cerrado es r_1663 (bicarbonate exchange).

# %%
for rxn in model_original_o2.exchanges:
    print(f"{rxn.id}: {rxn.name}")
# Out:
# r_1542: (1->3)-beta-D-glucan exchange
# r_1545: (R)-carnitine exchange
# r_1546: (R)-lactate exchange
# r_1547: (R)-mevalonate exchange
# r_1548: (R)-pantothenate exchange
# r_1549: (R,R)-2,3-butanediol exchange
# r_1550: (S)-3-methyl-2-oxopentanoate exchange
# r_1551: (S)-lactate exchange
# r_1552: (S)-malate exchange
# r_1553: 1-(sn-glycero-3-phospho)-1D-myo-inositol exchange
# r_1554: 1-acylglycerophosphocholine exchange
# r_1563: 2'-deoxyadenosine exchange
# r_1564: 2'-deoxyguanosine exchange
# r_1565: 2'-deoxyinosine exchange
# r_1566: 2'-deoxyuridine exchange
# r_1572: 2-isopropylmalate exchange
# r_1577: 2-methylbutanal exchange
# r_1580: 2-methylbutanol exchange
# r_1581: 2-methylbutyl acetate exchange
# r_1586: 2-oxoglutarate exchange
# r_1589: 2-phenylethanol exchange
# r_1598: 3-methylbutanal exchange
# r_1604: 4-aminobenzoate exchange
# r_1621: 5-aminolevulinate exchange
# r_1625: 5-formyltetrahydrofolic acid exchange
# r_1627: 7,8-diaminononanoate exchange
# r_1629: 8-amino-7-oxononanoate exchange
# r_1630: 9H-xanthine exchange
# r_1631: acetaldehyde exchange
# r_1634: acetate exchange
# r_1639: adenine exchange
# r_1641: adenosine 3',5'-bismonophosphate exchange
# r_1643: adenosine exchange
# r_1648: allantoate exchange
# r_1649: allantoin exchange
# r_1650: trehalose exchange
# r_1651: alpha-D-glucosamine 6-phosphate exchange
# r_1654: ammonium exchange
# r_1663: bicarbonate exchange
# r_1671: biotin exchange
# r_1672: carbon dioxide exchange
# r_1683: choline exchange
# r_1687: citrate exchange
# r_1702: cytidine exchange
# r_1705: cytosine exchange
# r_1706: D-arabinose exchange
# r_1709: D-fructose exchange
# r_1710: D-galactose exchange
# r_1711: D-galacturonate exchange
# r_1712: D-glucitol exchange
# r_1714: D-glucose exchange
# r_1715: D-mannose exchange
# r_1716: D-ribose exchange
# r_1718: D-xylose exchange
# r_1727: decanoate exchange
# r_1730: deoxycytidine exchange
# r_1749: dTTP exchange
# r_1753: episterol exchange
# r_1757: ergosterol exchange
# r_1761: ethanol exchange
# r_1764: ethanolamine exchange
# r_1765: ethyl acetate exchange
# r_1788: fecosterol exchange
# r_1791: FMN exchange
# r_1792: folic acid exchange
# r_1793: formate exchange
# r_1798: fumarate exchange
# r_1800: gamma-aminobutyrate exchange
# r_1806: glutathione disulfide exchange
# r_1807: glutathione exchange
# r_1808: glycerol exchange
# r_1810: L-glycine exchange
# r_1814: glycolaldehyde exchange
# r_1815: glyoxylate exchange
# r_1818: guanine exchange
# r_1820: guanosine exchange
# r_1832: H+ exchange
# r_1834: hexadecanal exchange
# r_1841: hypoxanthine exchange
# r_1843: indol-3-ylacetaldehyde exchange
# r_1847: inosine exchange
# r_1861: iron(2+) exchange
# r_1862: isoamyl acetate exchange
# r_1865: isoamylol exchange
# r_1866: isobutanol exchange
# r_1867: isobutyl acetate exchange
# r_1870: isobutyraldehyde exchange
# r_1873: L-alanine exchange
# r_1875: L-arabinitol exchange
# r_1878: L-arabinose exchange
# r_1879: L-arginine exchange
# r_1880: L-asparagine exchange
# r_1881: L-aspartate exchange
# r_1883: L-cysteine exchange
# r_1886: L-glucitol exchange
# r_1889: L-glutamate exchange
# r_1891: L-glutamine exchange
# r_1893: L-histidine exchange
# r_1896: L-homoserine exchange
# r_1897: L-isoleucine exchange
# r_1899: L-leucine exchange
# r_1900: L-lysine exchange
# r_1902: L-methionine exchange
# r_1903: L-phenylalanine exchange
# r_1904: L-proline exchange
# r_1906: L-serine exchange
# r_1909: L-sorbose exchange
# r_1911: L-threonine exchange
# r_1912: L-tryptophan exchange
# r_1913: L-tyrosine exchange
# r_1914: L-valine exchange
# r_1915: lanosterol exchange
# r_1916: laurate exchange
# r_1931: maltose exchange
# r_1947: myo-inositol exchange
# r_1952: N,N'-diformyldityrosine exchange
# r_1967: nicotinate exchange
# r_1968: NMN exchange
# r_1984: octanoate exchange
# r_1987: ornithine exchange
# r_1989: oxaloacetate(2-) exchange
# r_1992: oxygen exchange
# r_1993: palmitate exchange
# r_1994: palmitoleate exchange
# r_1999: pectin exchange
# r_2000: phenethyl acetate exchange
# r_2001: phenylacetaldehyde exchange
# r_2005: phosphate exchange
# r_2020: potassium exchange
# r_2024: putrescine exchange
# r_2028: pyridoxine exchange
# r_2033: pyruvate exchange
# r_2038: riboflavin exchange
# r_2043: S-adenosyl-L-methionine exchange
# r_2044: S-methyl-L-methionine exchange
# r_2046: sn-glycero-3-phosphocholine exchange
# r_2049: sodium exchange
# r_2051: spermidine exchange
# r_2052: spermine exchange
# r_2055: stearate exchange
# r_2056: succinate exchange
# r_2058: sucrose exchange
# r_2060: sulphate exchange
# r_2061: sulphite exchange
# r_2062: taurine exchange
# r_2066: thiamine(1+) diphosphate(1-) exchange
# r_2067: thiamine(1+) exchange
# r_2068: thiamine(1+) monophosphate exchange
# r_2073: thymidine exchange
# r_2083: tryptophol exchange
# r_2090: uracil exchange
# r_2091: urea exchange
# r_2092: uridine exchange
# r_2100: water exchange
# r_2102: xanthosine exchange
# r_2104: xylitol exchange
# r_2106: zymosterol exchange
# r_2134: 14-demethyllanosterol exchange
# r_2137: ergosta-5,7,22,24(28)-tetraen-3beta-ol exchange
# r_2187: butyrate exchange
# r_2188: hexanoate exchange
# r_2189: oleate exchange
# r_2193: myristate exchange
# r_4043: raffinose exchange
# r_4044: melibiose exchange
# r_4442: cysteamine exchange
# r_4494: methanol exchange
# r_4496: Ala-Gly exchange
# r_4497: 3-oxalomalate(3-) exchange
# r_4498: 6-O-alpha-D-glucopyranosyl-D-fructofuranose exchange
# r_4499: 5-dehydro-D-gluconate exchange
# r_4500: D-tagatose exchange
# r_4501: turanose exchange
# r_4502: D-glucose 6-phosphate exchange
# r_4503: alpha-maltotriose exchange
# r_4504: D-glucose 1-phosphate exchange
# r_4505: methyl alpha-D-glucopyranoside exchange
# r_4506: D-Glucosamine exchange
# r_4507: glycerone exchange
# r_4508: Ala-Gln exchange
# r_4509: Ala-Leu exchange
# r_4510: Gly-Gln exchange
# r_4511: Ala-His exchange
# r_4512: Gly-Asn exchange
# r_4513: Ala-Glu exchange
# r_4514: Gly-Met exchange
# r_4515: Ala-Asp exchange
# r_4516: Gly-Glu exchange
# r_4517: Ala-Thr exchange
# r_4518: Met-Ala exchange
# r_4519: L-citrulline exchange
# r_4520: 2-aminobutanoate exchange
# r_4521: choline phosphate exchange
# r_4522: glycerol 1-phosphate exchange
# r_4523: 2-phospho-D-glyceric acid exchange
# r_4524: GMP exchange
# r_4525: 3-phospho-serine exchange
# r_4526: O-phosphonatooxy-D-serine(2-) exchange
# r_4527: diphosphate exchange
# r_4528: triphosphate exchange
# r_4529: phosphoenolpyruvate exchange
# r_4530: N(omega)-phospho-L-arginine exchange
# r_4531: carbamoyl phosphate exchange
# r_4532: O-phosphoethanolamine exchange
# r_4533: cysteamine S-phosphate exchange
# r_4534: guanosine 2'-monophosphate exchange
# r_4535: glycerol 2-phosphate(2-) exchange
# r_4536: 3'-GMP exchange
# r_4537: 2-phosphoglycolate exchange
# r_4538: 6-phospho-D-gluconate exchange
# r_4539: D-mannose 6-phosphate exchange
# r_4540: 2',3'-cyclic GMP exchange
# r_4541: O(4)-phospho-L-tyrosine exchange
# r_4542: O-phospho-L-threonine exchange
# r_4543: 3-phosphonato-D-glycerate(3-) exchange
# r_4544: adenosine 2'-phosphate exchange
# r_4545: 3'-AMP exchange
# r_4546: 2',3'-cyclic AMP exchange
# r_4547: D-mannose 1-phosphate exchange
# r_4548: AMP exchange
# r_4549: N(alpha)-acetyl-L-methionine exchange
# r_4550: L-Methionine S-oxide exchange
# r_4551: 3-sulfino-L-alanine exchange
# r_4552: N-acetyl-L-cysteine exchange
# r_4553: L-cysteate exchange
# r_4554: 2-hydroxyethane-1-sulfonate exchange
# r_4555: acetoacetate exchange
# r_4556: N-acetyl-L-glutamate exchange
# r_4557: UMP exchange
# r_4558: CMP exchange
# r_4559: thymidine 5'-monophosphate exchange
# r_4560: thymidine 3'-monophosphate exchange
# r_4561: cytidine 2'-phosphate exchange
# r_4562: uridine 2'-phosphate exchange
# r_4563: 3'-UMP exchange
# r_4564: 2',3'-cyclic CMP exchange
# r_4565: 2',3'-cyclic UMP exchange
# r_4593: chloride exchange
# r_4594: Cu2(+) exchange
# r_4595: Mn(2+) exchange
# r_4596: Zn(2+) exchange
# r_4597: Mg(2+) exchange
# r_4600: Ca(2+) exchange
# r_4644: ethyl hexanoate exchange
# r_4645: ethyl octanoate exchange
# r_4646: ethyl butanoate exchange
# r_4647: hexyl acetate exchange
# r_4648: ethyl decanoate exchange
# r_4658: propanal exchange
# r_4659: propanol exchange
# r_4667: methional exchange
# r_4668: methionol exchange
# r_4676: (4-hydroxyphenyl)acetaldehyde exchange
# r_4677: tyrosol exchange
# r_4689: tyrosyl acetate exchange
# r_4692: methionyl acetate exchange
# r_4695: propyl acetate exchange
# r_4699: ethyl propionate exchange
# r_4708: hydrogen sulfide exchange
# r_4709: alkanesulfonate exchange
# r_4710: taurocholate exchange
# r_4727: ethyl-(2S)-lactate exchange
# r_4729: ethyl-(2R)-lactate exchange
# r_4731: diethyl-succinate exchange
# r_4733: monoethyl-succinate exchange
# r_4735: ethyl-benzoate exchange
# r_4737: ethyl-pyruvate exchange
# r_4739: benzyl-acetate exchange
# r_4741: ethyl-isobutyrate exchange
# r_4743: ethyl-2-methylbutyrate exchange
# r_4780: heme a exchange

# %%
res1 = cobra.flux_analysis.flux_variability_analysis(model_original_o2, model_original_o2.exchanges, fraction_of_optimum=0.9)

# %%
print(res1)
# Out:
#         minimum   maximum
# r_1542      0.0  0.000000
# r_1545      0.0  0.000000
# r_1546      0.0  0.174518
# r_1547      0.0  0.083836
# r_1548      0.0  0.042558
# ...         ...       ...
# r_4737      0.0  0.116112
# r_4739      0.0  0.000000
# r_4741      0.0  0.077299
# r_4743      0.0  0.063647
# r_4780      0.0  0.008785
#
# [271 rows x 2 columns]

# %% [markdown]
# ## Modelo sin O2

# %%
# model_original_sin_o2.reactions.get_by_id("r_1992").lower_bound = 0 # consumo de oxígeno a 0
print(f"Lower bound oxígeno: {model_original_sin_o2.exchanges.get_by_id('r_1992').lower_bound}")
results = model_original_sin_o2.optimize()
results_pfba = cobra.flux_analysis.pfba(model_original_sin_o2)
print(f"Flujo óptimo sin O2 (FBA): {results.objective_value}")
print(f"Etanol (FBA): {model_original_sin_o2.exchanges.get_by_id('r_1761').flux}")
print(f"Flujo óptimo sin O2 (pFBA): {results_pfba.objective_value}")
print(f"Etanol (pFBA): {model_original_sin_o2.exchanges.get_by_id('r_1761').flux}")
# Out:
# Lower bound oxígeno: 0.0
# Flujo óptimo sin O2 (FBA): 0.9507629154378835
# Etanol (FBA): 59.35242208925405
# Flujo óptimo sin O2 (pFBA): 1198.7073349740208
# Etanol (pFBA): 59.35242208925405

# %%
# agregamos manualmente glucosa y fructosa
print(f"Glucosa: {model_original_sin_o2.exchanges.get_by_id('r_1714').lower_bound}")
print(f"Fructosa: {model_original_sin_o2.exchanges.get_by_id('r_1709').lower_bound}")
# Out:
# Glucosa: -20.0
# Fructosa: -20.0

# %% [markdown]
# ## Medio de cultivo para condiciones enológicas:

# %% [markdown]
# <img src="Captura de pantalla 2026-02-24 111018.png" width="500">

# %%
medio_enologico = [
    # "r_1714","r_1709",      # CARBONO: D-glucose, D-fructose
    "r_1687","r_1552",      # ÁCIDOS ORGÁNICOS: citrate, (S)-malate
    "r_2005","r_2060",      # SALES/IONES: phosphate, sulphate
    "r_2020","r_2049",      # potassium, sodium 
    "r_4593","r_4600",      # chloride, Ca2+
    "r_4597","r_4595",      # Mg2+, Mn2+
    "r_4596","r_4594",      # Zn2+, Cu2+
    "r_1947","r_1967",      # VITAMINAS: myo-inositol, nicotinate
    "r_1548","r_2067",      # (R)-pantothenate, thiamine(1+)
    "r_2028","r_1671",      # pyridoxine, biotin
    "r_1757","r_2189",      # FACTORES ANAERÓBICOS: ergosterol, oleate
    "r_1654",               # ammonium
    "r_1873","r_1879",      # AMINOÁCIDOS: alanine, arginine
    "r_1881","r_1889",      # aspartate, glutamate
    "r_1891","r_1893",      # glutamine, histidine
    "r_1897","r_1899",      # isoleucine, leucine
    "r_1900","r_1902",      # lysine, methionine
    "r_1903","r_1906",      # phenylalanine, proline
    "r_1911","r_1912",      # threonine, tryptophan
    "r_1913","r_1914",      # tyrosine, valine
    "r_1810",               # glycine
    # EXTRAS PARA QUE FUNCIONE MODELO:
    "r_1832",               # H+
    "r_1861",               # iron(2+)
    "r_2100"                 # water
]

# %%
# Cerramos todos los lower bounds de las reacciones de exchange
for rxn in model_modificado.exchanges:
    rxn.lower_bound = 0
        
# Revisamos que se hayan cerrado correctamente con el intercambio de amonio:
print(f"Antes {model_modificado.exchanges.get_by_id('r_1654').name} (límite: {model_modificado.exchanges.get_by_id('r_1654').lower_bound})")
for reaction in medio_enologico:
    model_modificado.exchanges.get_by_id(reaction).lower_bound = -1000
print(f"Después {model_modificado.exchanges.get_by_id('r_1654').name} (límite: {model_modificado.exchanges.get_by_id('r_1654').lower_bound})")

# agregamos manualmente glucosa y fructosa
model_modificado.exchanges.get_by_id('r_1714').lower_bound = -20.0
model_modificado.exchanges.get_by_id('r_1709').lower_bound = -20.0
    
# Asegurar anaerobiosis:
model_modificado.reactions.get_by_id("r_1992").lower_bound = 0.0 # consumo de oxígeno a 0

# model_modificado.reactions.get_by_id("r_1992").lower_bound = -1000 # consumo de oxígeno a 1000

print(f"Lower bound de O_2: {model_modificado.reactions.get_by_id('r_1992').lower_bound}")

    
results_medio = model_modificado.optimize()
results_medio_pfba = cobra.flux_analysis.pfba(model_modificado)

print(f"Flujo óptimo con medio definido (FBA): {results_medio.objective_value}")
print(f"Etanol (FBA): {model_modificado.exchanges.get_by_id('r_1761').flux}")
print(f"Flujo óptimo con medio definido (pFBA): {results_medio_pfba.objective_value}")
print(f"Etanol (pFBA): {model_modificado.exchanges.get_by_id('r_1761').flux}")
# Out:
# Antes ammonium exchange (límite: 0)
# Después ammonium exchange (límite: -1000)
# Lower bound de O_2: 0.0
# Flujo óptimo con medio definido (FBA): 0.0
# Etanol (FBA): 0.0
# Flujo óptimo con medio definido (pFBA): 0.0
# Etanol (pFBA): 0.0

# %% [markdown]
# ## Simulación con dFBA

# %%
i=1
for exchange_reactions in model_original_o2.exchanges:
  print(f"Exchange reactiones n°{i}: {exchange_reactions.id}")
  i+=1
  
print(len(model_original_o2.exchanges))
# Out:
# Exchange reactiones n°1: r_1542
# Exchange reactiones n°2: r_1545
# Exchange reactiones n°3: r_1546
# Exchange reactiones n°4: r_1547
# Exchange reactiones n°5: r_1548
# Exchange reactiones n°6: r_1549
# Exchange reactiones n°7: r_1550
# Exchange reactiones n°8: r_1551
# Exchange reactiones n°9: r_1552
# Exchange reactiones n°10: r_1553
# Exchange reactiones n°11: r_1554
# Exchange reactiones n°12: r_1563
# Exchange reactiones n°13: r_1564
# Exchange reactiones n°14: r_1565
# Exchange reactiones n°15: r_1566
# Exchange reactiones n°16: r_1572
# Exchange reactiones n°17: r_1577
# Exchange reactiones n°18: r_1580
# Exchange reactiones n°19: r_1581
# Exchange reactiones n°20: r_1586
# Exchange reactiones n°21: r_1589
# Exchange reactiones n°22: r_1598
# Exchange reactiones n°23: r_1604
# Exchange reactiones n°24: r_1621
# Exchange reactiones n°25: r_1625
# Exchange reactiones n°26: r_1627
# Exchange reactiones n°27: r_1629
# Exchange reactiones n°28: r_1630
# Exchange reactiones n°29: r_1631
# Exchange reactiones n°30: r_1634
# Exchange reactiones n°31: r_1639
# Exchange reactiones n°32: r_1641
# Exchange reactiones n°33: r_1643
# Exchange reactiones n°34: r_1648
# Exchange reactiones n°35: r_1649
# Exchange reactiones n°36: r_1650
# Exchange reactiones n°37: r_1651
# Exchange reactiones n°38: r_1654
# Exchange reactiones n°39: r_1663
# Exchange reactiones n°40: r_1671
# Exchange reactiones n°41: r_1672
# Exchange reactiones n°42: r_1683
# Exchange reactiones n°43: r_1687
# Exchange reactiones n°44: r_1702
# Exchange reactiones n°45: r_1705
# Exchange reactiones n°46: r_1706
# Exchange reactiones n°47: r_1709
# Exchange reactiones n°48: r_1710
# Exchange reactiones n°49: r_1711
# Exchange reactiones n°50: r_1712
# Exchange reactiones n°51: r_1714
# Exchange reactiones n°52: r_1715
# Exchange reactiones n°53: r_1716
# Exchange reactiones n°54: r_1718
# Exchange reactiones n°55: r_1727
# Exchange reactiones n°56: r_1730
# Exchange reactiones n°57: r_1749
# Exchange reactiones n°58: r_1753
# Exchange reactiones n°59: r_1757
# Exchange reactiones n°60: r_1761
# Exchange reactiones n°61: r_1764
# Exchange reactiones n°62: r_1765
# Exchange reactiones n°63: r_1788
# Exchange reactiones n°64: r_1791
# Exchange reactiones n°65: r_1792
# Exchange reactiones n°66: r_1793
# Exchange reactiones n°67: r_1798
# Exchange reactiones n°68: r_1800
# Exchange reactiones n°69: r_1806
# Exchange reactiones n°70: r_1807
# Exchange reactiones n°71: r_1808
# Exchange reactiones n°72: r_1810
# Exchange reactiones n°73: r_1814
# Exchange reactiones n°74: r_1815
# Exchange reactiones n°75: r_1818
# Exchange reactiones n°76: r_1820
# Exchange reactiones n°77: r_1832
# Exchange reactiones n°78: r_1834
# Exchange reactiones n°79: r_1841
# Exchange reactiones n°80: r_1843
# Exchange reactiones n°81: r_1847
# Exchange reactiones n°82: r_1861
# Exchange reactiones n°83: r_1862
# Exchange reactiones n°84: r_1865
# Exchange reactiones n°85: r_1866
# Exchange reactiones n°86: r_1867
# Exchange reactiones n°87: r_1870
# Exchange reactiones n°88: r_1873
# Exchange reactiones n°89: r_1875
# Exchange reactiones n°90: r_1878
# Exchange reactiones n°91: r_1879
# Exchange reactiones n°92: r_1880
# Exchange reactiones n°93: r_1881
# Exchange reactiones n°94: r_1883
# Exchange reactiones n°95: r_1886
# Exchange reactiones n°96: r_1889
# Exchange reactiones n°97: r_1891
# Exchange reactiones n°98: r_1893
# Exchange reactiones n°99: r_1896
# Exchange reactiones n°100: r_1897
# Exchange reactiones n°101: r_1899
# Exchange reactiones n°102: r_1900
# Exchange reactiones n°103: r_1902
# Exchange reactiones n°104: r_1903
# Exchange reactiones n°105: r_1904
# Exchange reactiones n°106: r_1906
# Exchange reactiones n°107: r_1909
# Exchange reactiones n°108: r_1911
# Exchange reactiones n°109: r_1912
# Exchange reactiones n°110: r_1913
# Exchange reactiones n°111: r_1914
# Exchange reactiones n°112: r_1915
# Exchange reactiones n°113: r_1916
# Exchange reactiones n°114: r_1931
# Exchange reactiones n°115: r_1947
# Exchange reactiones n°116: r_1952
# Exchange reactiones n°117: r_1967
# Exchange reactiones n°118: r_1968
# Exchange reactiones n°119: r_1984
# Exchange reactiones n°120: r_1987
# Exchange reactiones n°121: r_1989
# Exchange reactiones n°122: r_1992
# Exchange reactiones n°123: r_1993
# Exchange reactiones n°124: r_1994
# Exchange reactiones n°125: r_1999
# Exchange reactiones n°126: r_2000
# Exchange reactiones n°127: r_2001
# Exchange reactiones n°128: r_2005
# Exchange reactiones n°129: r_2020
# Exchange reactiones n°130: r_2024
# Exchange reactiones n°131: r_2028
# Exchange reactiones n°132: r_2033
# Exchange reactiones n°133: r_2038
# Exchange reactiones n°134: r_2043
# Exchange reactiones n°135: r_2044
# Exchange reactiones n°136: r_2046
# Exchange reactiones n°137: r_2049
# Exchange reactiones n°138: r_2051
# Exchange reactiones n°139: r_2052
# Exchange reactiones n°140: r_2055
# Exchange reactiones n°141: r_2056
# Exchange reactiones n°142: r_2058
# Exchange reactiones n°143: r_2060
# Exchange reactiones n°144: r_2061
# Exchange reactiones n°145: r_2062
# Exchange reactiones n°146: r_2066
# Exchange reactiones n°147: r_2067
# Exchange reactiones n°148: r_2068
# Exchange reactiones n°149: r_2073
# Exchange reactiones n°150: r_2083
# Exchange reactiones n°151: r_2090
# Exchange reactiones n°152: r_2091
# Exchange reactiones n°153: r_2092
# Exchange reactiones n°154: r_2100
# Exchange reactiones n°155: r_2102
# Exchange reactiones n°156: r_2104
# Exchange reactiones n°157: r_2106
# Exchange reactiones n°158: r_2134
# Exchange reactiones n°159: r_2137
# Exchange reactiones n°160: r_2187
# Exchange reactiones n°161: r_2188
# Exchange reactiones n°162: r_2189
# Exchange reactiones n°163: r_2193
# Exchange reactiones n°164: r_4043
# Exchange reactiones n°165: r_4044
# Exchange reactiones n°166: r_4442
# Exchange reactiones n°167: r_4494
# Exchange reactiones n°168: r_4496
# Exchange reactiones n°169: r_4497
# Exchange reactiones n°170: r_4498
# Exchange reactiones n°171: r_4499
# Exchange reactiones n°172: r_4500
# Exchange reactiones n°173: r_4501
# Exchange reactiones n°174: r_4502
# Exchange reactiones n°175: r_4503
# Exchange reactiones n°176: r_4504
# Exchange reactiones n°177: r_4505
# Exchange reactiones n°178: r_4506
# Exchange reactiones n°179: r_4507
# Exchange reactiones n°180: r_4508
# Exchange reactiones n°181: r_4509
# Exchange reactiones n°182: r_4510
# Exchange reactiones n°183: r_4511
# Exchange reactiones n°184: r_4512
# Exchange reactiones n°185: r_4513
# Exchange reactiones n°186: r_4514
# Exchange reactiones n°187: r_4515
# Exchange reactiones n°188: r_4516
# Exchange reactiones n°189: r_4517
# Exchange reactiones n°190: r_4518
# Exchange reactiones n°191: r_4519
# Exchange reactiones n°192: r_4520
# Exchange reactiones n°193: r_4521
# Exchange reactiones n°194: r_4522
# Exchange reactiones n°195: r_4523
# Exchange reactiones n°196: r_4524
# Exchange reactiones n°197: r_4525
# Exchange reactiones n°198: r_4526
# Exchange reactiones n°199: r_4527
# Exchange reactiones n°200: r_4528
# Exchange reactiones n°201: r_4529
# Exchange reactiones n°202: r_4530
# Exchange reactiones n°203: r_4531
# Exchange reactiones n°204: r_4532
# Exchange reactiones n°205: r_4533
# Exchange reactiones n°206: r_4534
# Exchange reactiones n°207: r_4535
# Exchange reactiones n°208: r_4536
# Exchange reactiones n°209: r_4537
# Exchange reactiones n°210: r_4538
# Exchange reactiones n°211: r_4539
# Exchange reactiones n°212: r_4540
# Exchange reactiones n°213: r_4541
# Exchange reactiones n°214: r_4542
# Exchange reactiones n°215: r_4543
# Exchange reactiones n°216: r_4544
# Exchange reactiones n°217: r_4545
# Exchange reactiones n°218: r_4546
# Exchange reactiones n°219: r_4547
# Exchange reactiones n°220: r_4548
# Exchange reactiones n°221: r_4549
# Exchange reactiones n°222: r_4550
# Exchange reactiones n°223: r_4551
# Exchange reactiones n°224: r_4552
# Exchange reactiones n°225: r_4553
# Exchange reactiones n°226: r_4554
# Exchange reactiones n°227: r_4555
# Exchange reactiones n°228: r_4556
# Exchange reactiones n°229: r_4557
# Exchange reactiones n°230: r_4558
# Exchange reactiones n°231: r_4559
# Exchange reactiones n°232: r_4560
# Exchange reactiones n°233: r_4561
# Exchange reactiones n°234: r_4562
# Exchange reactiones n°235: r_4563
# Exchange reactiones n°236: r_4564
# Exchange reactiones n°237: r_4565
# Exchange reactiones n°238: r_4593
# Exchange reactiones n°239: r_4594
# Exchange reactiones n°240: r_4595
# Exchange reactiones n°241: r_4596
# Exchange reactiones n°242: r_4597
# Exchange reactiones n°243: r_4600
# Exchange reactiones n°244: r_4644
# Exchange reactiones n°245: r_4645
# Exchange reactiones n°246: r_4646
# Exchange reactiones n°247: r_4647
# Exchange reactiones n°248: r_4648
# Exchange reactiones n°249: r_4658
# Exchange reactiones n°250: r_4659
# Exchange reactiones n°251: r_4667
# Exchange reactiones n°252: r_4668
# Exchange reactiones n°253: r_4676
# Exchange reactiones n°254: r_4677
# Exchange reactiones n°255: r_4689
# Exchange reactiones n°256: r_4692
# Exchange reactiones n°257: r_4695
# Exchange reactiones n°258: r_4699
# Exchange reactiones n°259: r_4708
# Exchange reactiones n°260: r_4709
# Exchange reactiones n°261: r_4710
# Exchange reactiones n°262: r_4727
# Exchange reactiones n°263: r_4729
# Exchange reactiones n°264: r_4731
# Exchange reactiones n°265: r_4733
# Exchange reactiones n°266: r_4735
# Exchange reactiones n°267: r_4737
# Exchange reactiones n°268: r_4739
# Exchange reactiones n°269: r_4741
# Exchange reactiones n°270: r_4743
# Exchange reactiones n°271: r_4780
# 271

# %%
init = np.zeros(272)
# BUSCAMOS NITRÓGENO, O2, GLUCOSA Y FRUCTUSA
i=1
for exchange_reactions in model_original_o2.exchanges:
    if exchange_reactions.id == "r_1654":
        print(f"Exchange reactiones n°{i}: {exchange_reactions.name}")
    elif exchange_reactions.id == "r_1992": 
        print(f"Exchange reactiones n°{i}: {exchange_reactions.name}")
    elif exchange_reactions.id == "r_1714": 
        print(f"Exchange reactiones n°{i}: {exchange_reactions.name}")
    elif exchange_reactions.id == "r_1709": 
        print(f"Exchange reactiones n°{i}: {exchange_reactions.name}")
    elif exchange_reactions.id == "r_1761":
        print(f"Exchange reactiones n°{i}: {exchange_reactions.name}")
    i+=1
# Out:
# Exchange reactiones n°38: ammonium exchange
# Exchange reactiones n°47: D-fructose exchange
# Exchange reactiones n°51: D-glucose exchange
# Exchange reactiones n°60: ethanol exchange
# Exchange reactiones n°122: oxygen exchange

# %%
# Revisamos si el medio enológico está definido:
for rxn in model_modificado.exchanges:
    if rxn.lower_bound < 0:  # Solo reacciones de importación
        print(f"{rxn.id}: {rxn.name} (límite: {rxn.lower_bound})")
# Out:
# r_1548: (R)-pantothenate exchange (límite: -1000)
# r_1552: (S)-malate exchange (límite: -1000)
# r_1654: ammonium exchange (límite: -1000)
# r_1671: biotin exchange (límite: -1000)
# r_1687: citrate exchange (límite: -1000)
# r_1709: D-fructose exchange (límite: -20.0)
# r_1714: D-glucose exchange (límite: -20.0)
# r_1757: ergosterol exchange (límite: -1000)
# r_1810: L-glycine exchange (límite: -1000)
# r_1832: H+ exchange (límite: -1000)
# r_1861: iron(2+) exchange (límite: -1000)
# r_1873: L-alanine exchange (límite: -1000)
# r_1879: L-arginine exchange (límite: -1000)
# r_1881: L-aspartate exchange (límite: -1000)
# r_1889: L-glutamate exchange (límite: -1000)
# r_1891: L-glutamine exchange (límite: -1000)
# r_1893: L-histidine exchange (límite: -1000)
# r_1897: L-isoleucine exchange (límite: -1000)
# r_1899: L-leucine exchange (límite: -1000)
# r_1900: L-lysine exchange (límite: -1000)
# r_1902: L-methionine exchange (límite: -1000)
# r_1903: L-phenylalanine exchange (límite: -1000)
# r_1906: L-serine exchange (límite: -1000)
# r_1911: L-threonine exchange (límite: -1000)
# r_1912: L-tryptophan exchange (límite: -1000)
# r_1913: L-tyrosine exchange (límite: -1000)
# r_1914: L-valine exchange (límite: -1000)
# r_1947: myo-inositol exchange (límite: -1000)
# r_1967: nicotinate exchange (límite: -1000)
# r_2005: phosphate exchange (límite: -1000)
# r_2020: potassium exchange (límite: -1000)
# r_2028: pyridoxine exchange (límite: -1000)
# r_2049: sodium exchange (límite: -1000)
# r_2060: sulphate exchange (límite: -1000)
# r_2067: thiamine(1+) exchange (límite: -1000)
# r_2100: water exchange (límite: -1000)
# r_2189: oleate exchange (límite: -1000)
# r_4593: chloride exchange (límite: -1000)
# r_4594: Cu2(+) exchange (límite: -1000)
# r_4595: Mn(2+) exchange (límite: -1000)
# r_4596: Zn(2+) exchange (límite: -1000)
# r_4597: Mg(2+) exchange (límite: -1000)
# r_4600: Ca(2+) exchange (límite: -1000)

# %% [markdown]
# ### dFBA modelo original

# %%
import numpy as np
import warnings
import contextlib
import io

def dFBA(model_original, limited_substrate, o2_index, init_concentrations, t_span = (0, 100), t_eval = np.linspace(0, 100, 100), params = (1, 0.1)):
    """
    Simulates cell growth and substrate consumption using dynamic Flux Balance Analysis (dFBA).
    This function integrates a system of ODEs where biomass and metabolite concentrations are updated over time,
    and metabolic fluxes are determined by FBA optimization at each time step.

    Note:
        The first element of the state vector corresponds to biomass. Substrate and metabolite indices must be offset accordingly.
        Ensure that the indices for limited_substrate and o2_index refer to the correct positions in model.exchanges.

    Args:
        model_original: The original metabolic model (e.g., cobra.Model).
        limited_substrate (int): Index of the limiting substrate in the model's exchange list.
        o2_index (int): Index of the oxygen exchange in the model's exchange list.
        init_concentrations (array-like): Initial concentrations [biomass, substrates...].
        t_span (tuple, optional): Time interval for the simulation (start, end). Default is (0, 10).
        t_eval (array-like, optional): Time points at which the solution is evaluated. Default is np.linspace(0, 10, 100).
        params (tuple, optional): Kinetic parameters (v_max, k_s) for the Michaelis-Menten equation of the limiting substrate. Default is (1, 0.1).

    Returns:
        sol: Solution object from scipy.integrate.solve_ivp containing the time course of biomass and metabolite concentrations.
    """


    with contextlib.redirect_stdout(io.StringIO()), contextlib.redirect_stderr(io.StringIO()), warnings.catch_warnings():
        warnings.simplefilter("ignore")
        model = model_original.copy()
        v_max, k_s = params

        def system_dynamics(t, y):
            
            X = y[0]
            S = y[limited_substrate + 1]
            O = y[o2_index + 1]

            model.exchanges[limited_substrate].lower_bound = - v_max * S / (k_s + S)

            if O <= 0:
                model.exchanges[o2_index].lower_bound = 0.0
            
            
            sol = model.optimize()
            
            dydt = np.zeros_like(y)

            if sol.status != 'optimal':
            # Si el modelo es infactible, dydt se mantiene en ceros
                pass
            else:
                dydt[0]     = sol.objective_value * X  # Tasa de crecimiento
                dydt[1:]    = sol.fluxes[[rxn.id for rxn in model.exchanges]] * X # Flujos metabólicos

                # Fix for negative concentrations
                dydt[(y <= 1e-6) & (np.concatenate(([sol.objective_value], sol.fluxes[[rxn.id for rxn in model.exchanges]])) <= 1e-6)] = 0
                
            return dydt


        sol = solve_ivp(
            fun=system_dynamics,
            t_span=t_span,
            t_eval=t_eval,
            y0=init_concentrations,
            rtol=1e-8,
            atol=1e-8,
            method='RK45')

    return sol

# %%
init[0] = 0.01 # biomasa
init[38] = 100 # nitrógeno
init[47] = 100 # fructosa
init[51] = 20 # glucosa
init[122] = 5 # oxígeno

# %%
sol1 = dFBA(model_original_o2, int(50), int(121), init, t_span = (0, 500), t_eval = np.linspace(0, 500, 10),params = (50, 1))

# %%
fig, axes = plt.subplots(2,2, figsize=(15,10))

axes[0,0].plot(sol1.t, sol1.y[0], '*-r')
axes[0,0].set_xlabel('Tiempo')
axes[0,0].set_ylabel('Biomasa')
axes[0,0].set_title('Biomasa')
axes[0,0].grid(True)

axes[0,1].plot(sol1.t, sol1.y[51], '*-b')
axes[0,1].set_xlabel('Tiempo')
axes[0,1].set_ylabel('Concentración')
axes[0,1].set_title('Azúcares')
axes[0,1].grid(True)

axes[1,0].plot(sol1.t, sol1.y[60], '*-b')
axes[1,0].set_xlabel('Tiempo')
axes[1,0].set_ylabel('Etanol')
axes[1,0].set_title('Etanol')
axes[1,0].grid(True)

axes[1,1].plot(sol1.t, sol1.y[122], '*-g')
axes[1,1].set_xlabel('Tiempo')
axes[1,1].set_ylabel('Oxígeno')
axes[1,1].set_title('Oxígeno')
axes[1,1].grid(True)

fig.suptitle("Modelo Yeast9 en condiciones aeróbicas")
fig.tight_layout()

# %% [markdown]
# SI SACO EL $O_2$ NO CRECE!!!

# %% [markdown]
# ### dFBA con modelo original y $O_2$ = 0

# %%
init2 = np.zeros(272)
init2[0] = 0.01 # biomasa
init2[38] = 100 # nitrógeno
init2[47] = 100 # fructosa
init2[51] = 20 # glucosa
init2[122] = 0 # oxígeno

# model_original_sin_o2.reactions.get_by_id("r_1992").lower_bound = -1

# %%
sol2 = dFBA(model_original_sin_o2, int(50), int(121), init2, t_span = (0, 500), t_eval = np.linspace(0, 500, 10),params = (50, 1))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 sol2 = dFBA(model_original_sin_o2, int(50), int(121), init2, t_span = (0, 500), t_eval = np.linspace(0, 500, 10),params = (50, 1))
#
# Cell In[27], line 64, in dFBA(model_original, limited_substrate, o2_index, init_concentrations, t_span, t_eval, params)
#      59             dydt[(y <= 1e-6) & (np.concatenate(([sol.objective_value], sol.fluxes[[rxn.id for rxn in model.exchanges]])) <= 1e-6)] = 0
#      61         return dydt
# ---> 64     sol = solve_ivp(
#      65         fun=system_dynamics,
#      66         t_span=t_span,
#      67         t_eval=t_eval,
#      68         y0=init_concentrations,
#      69         rtol=1e-8,
#      70         atol=1e-8,
#      71         method='RK45')
#      73 return sol
#
# File c:\Users\MARIA\anaconda3\envs\mi_env\lib\site-packages\scipy\integrate\_ivp\ivp.py:655, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     653 status = None
#     654 while status is None:
# --> 655     message = solver.step()
#     657     if solver.status == 'finished':
#     658         status = 0
#
# File c:\Users\MARIA\anaconda3\envs\mi_env\lib\site-packages\scipy\integrate\_ivp\base.py:197, in OdeSolver.step(self)
#     195 else:
#     196     t = self.t
# --> 197     success, message = self._step_impl()
#     199     if not success:
#     200         self.status = 'failed'
#
# File c:\Users\MARIA\anaconda3\envs\mi_env\lib\site-packages\scipy\integrate\_ivp\rk.py:144, in RungeKutta._step_impl(self)
#     141 h = t_new - t
#     142 h_abs = np.abs(h)
# --> 144 y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                        self.B, self.C, self.K)
#     146 scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#     147 error_norm = self._estimate_error_norm(self.K, h, scale)
#
# File c:\Users\MARIA\anaconda3\envs\mi_env\lib\site-packages\scipy\integrate\_ivp\rk.py:64, in rk_step(fun, t, y, f, h, A, B, C, K)
#      62 for s, (a, c) in enumerate(zip(A[1:], C[1:]), start=1):
#      63     dy = np.dot(K[:s].T, a[:s]) * h
# ---> 64     K[s] = fun(t + c * h, y + dy)
#      66 y_new = y + h * np.dot(K[:-1].T, B)
#      67 f_new = fun(t + h, y_new)
#
# File c:\Users\MARIA\anaconda3\envs\mi_env\lib\site-packages\scipy\integrate\_ivp\base.py:154, in OdeSolver.__init__.<locals>.fun(t, y)
#     152 def fun(t, y):
#     153     self.nfev += 1
# --> 154     return self.fun_single(t, y)
#
# File c:\Users\MARIA\anaconda3\envs\mi_env\lib\site-packages\scipy\integrate\_ivp\base.py:23, in check_arguments.<locals>.fun_wrapped(t, y)
#      22 def fun_wrapped(t, y):
# ---> 23     return np.asarray(fun(t, y), dtype=dtype)
#
# Cell In[27], line 41, in dFBA.<locals>.system_dynamics(t, y)
#      38 S = y[limited_substrate + 1]
#      39 O = y[o2_index + 1]
# ---> 41 model.exchanges[limited_substrate].lower_bound = - v_max * S / (k_s + S)
#      43 if O <= 0:
#      44     model.exchanges[o2_index].lower_bound = 0.0
#
# File c:\Users\MARIA\anaconda3\envs\mi_env\lib\site-packages\cobra\core\model.py:1065, in Model.exchanges(self)
#    1049 @property
#    1050 def exchanges(self) -> List[Reaction]:
#    1051     """Exchange reactions in model.
#    1052
#    1053     Reactions that exchange mass with the exterior. Uses annotations
#    (...)
#    1063     cobra.medium.find_boundary_types
#    1064     """
# -> 1065     return find_boundary_types(self, "exchange", None)
#
# File c:\Users\MARIA\anaconda3\envs\mi_env\lib\site-packages\cobra\medium\boundary_types.py:190, in find_boundary_types(model, boundary_type, external_compartment)
#     188     return []
#     189 if external_compartment is None:
# --> 190     external_compartment = find_external_compartment(model)
#     191 return model.reactions.query(
#     192     lambda r: is_boundary_type(r, boundary_type, external_compartment)
#     193 )
#
# File c:\Users\MARIA\anaconda3\envs\mi_env\lib\site-packages\cobra\medium\boundary_types.py:53, in find_external_compartment(model)
#      29 def find_external_compartment(model: "Model") -> str:
#      30     """Find the external compartment in the model.
#      31
#      32     Uses a simple heuristic where the external compartment should be the
#    (...)
#      51
#      52     """
# ---> 53     if model.boundary:
#      54         counts = pd.Series(tuple(r.compartments)[0] for r in model.boundary)
#      55         most = counts.value_counts()
#
# File c:\Users\MARIA\anaconda3\envs\mi_env\lib\site-packages\cobra\core\model.py:1047, in Model.boundary(self)
#    1035 @property
#    1036 def boundary(self) -> List[Reaction]:
#    1037     """Boundary reactions in the model.
#    1038
#    1039     Reactions that either have no substrate or product.
#    (...)
#    1045         only one metabolite overall.
#    1046     """
# -> 1047     return [rxn for rxn in self.reactions if rxn.boundary]
#
# File c:\Users\MARIA\anaconda3\envs\mi_env\lib\site-packages\cobra\core\model.py:1047, in <listcomp>(.0)
#    1035 @property
#    1036 def boundary(self) -> List[Reaction]:
#    1037     """Boundary reactions in the model.
#    1038
#    1039     Reactions that either have no substrate or product.
#    (...)
#    1045         only one metabolite overall.
#    1046     """
# -> 1047     return [rxn for rxn in self.reactions if rxn.boundary]
#
# File c:\Users\MARIA\anaconda3\envs\mi_env\lib\site-packages\cobra\core\reaction.py:812, in Reaction.boundary(self)
#     799     """Set reversiblitly (ignored).
#     800
#     801     At this stage this is not set and is ignored. Present for compatiblity reasons.
#    (...)
#     808         This value is ignored.
#     809     """
#     810     warn("Setting reaction reversibility is ignored")
# --> 812 @property
#     813 def boundary(self) -> bool:
#     814     """Whether or not this reaction is an exchange reaction.
#     815
#     816     Returns
#     817     -------
#     818     bool:   `True` if the reaction has either no products or reactants.
#     819     """
#     820     return len(self.metabolites) == 1 and not (self.reactants and self.products)
#
# KeyboardInterrupt:

# %%
fig, axes = plt.subplots(2,2, figsize=(15,10))

axes[0,0].plot(sol2.t, sol2.y[0], '*-r')
axes[0,0].set_xlabel('Tiempo')
axes[0,0].set_ylabel('Biomasa')
axes[0,0].set_title('Biomasa')
axes[0,0].grid(True)

axes[0,1].plot(sol2.t, sol2.y[51], '*-b')
axes[0,1].set_xlabel('Tiempo')
axes[0,1].set_ylabel('Concentración')
axes[0,1].set_title('Azúcares')
axes[0,1].grid(True)

axes[1,0].plot(sol2.t, sol2.y[60], '*-b')
axes[1,0].set_xlabel('Tiempo')
axes[1,0].set_ylabel('Etanol')
axes[1,0].set_title('Etanol')
axes[1,0].grid(True)

axes[1,1].plot(sol2.t, sol2.y[122], '*-g')
axes[1,1].set_xlabel('Tiempo')
axes[1,1].set_ylabel('Oxígeno')
axes[1,1].set_title('Oxígeno')
axes[1,1].grid(True)

fig.suptitle("Modelo Yeast9 en condiciones anaeróbicas")
fig.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 fig, axes = plt.subplots(2,2, figsize=(15,10))
# ----> 3 axes[0,0].plot(sol2.t, sol2.y[0], '*-r')
#       4 axes[0,0].set_xlabel('Tiempo')
#       5 axes[0,0].set_ylabel('Biomasa')
#
# NameError: name 'sol2' is not defined

# %% [markdown]
# Creo que para que funcione de manera anaeróbica, se debe dejar el lower bound como "abierto" (lo dejé en -1), y que la concentración inicial de la ODE sea 0.

# %% [markdown]
# ### dFBA con medio enológico

# %%
sol3 = dFBA(model_modificado, int(50), int(121), init2, t_span = (0, 500), t_eval = np.linspace(0, 500, 10),params = (50, 1))

# %%
fig, axes = plt.subplots(2,2, figsize=(15,10))

axes[0,0].plot(sol3.t, sol3.y[0], '*-r')
axes[0,0].set_xlabel('Tiempo')
axes[0,0].set_ylabel('Biomasa')
axes[0,0].set_title('Biomasa')
axes[0,0].grid(True)

axes[0,1].plot(sol3.t, sol3.y[51], '*-b')
axes[0,1].set_xlabel('Tiempo')
axes[0,1].set_ylabel('Concentración')
axes[0,1].set_title('Azúcares')
axes[0,1].grid(True)

axes[1,0].plot(sol3.t, sol3.y[60], '*-b')
axes[1,0].set_xlabel('Tiempo')
axes[1,0].set_ylabel('Etanol')
axes[1,0].set_title('Etanol')
axes[1,0].grid(True)

axes[1,1].plot(sol3.t, sol3.y[122], '*-g')
axes[1,1].set_xlabel('Tiempo')
axes[1,1].set_ylabel('Oxígeno')
axes[1,1].set_title('Oxígeno')
axes[1,1].grid(True)

fig.suptitle("Modelo Yeast9 en condiciones anaeróbicas y medio enológico")
fig.tight_layout()

# %% [markdown]
# ### Gráficos:

# %%
fig, axes = plt.subplots(2,2, figsize=(15,10))

axes[0,0].plot(sol1.t, sol1.y[0], '-r', label="Original")
axes[0,0].plot(sol2.t, sol2.y[0], ':r', label = "Original y O_2=0")
axes[0,0].plot(sol3.t, sol3.y[0], '--r', label = "Medio enológico y O_2 = 0")
axes[0,0].set_xlabel('Tiempo')
axes[0,0].set_ylabel('Biomasa')
axes[0,0].set_title('Biomasa')
axes[0,0].grid(True)

# axes[0,1].plot(sol1.t, sol1.y[51], '*-b')
axes[0,1].plot(sol1.t, sol1.y[51], '-b', label="Original")
axes[0,1].plot(sol2.t, sol2.y[51], ':b', label = "Original y O_2=0")
axes[0,1].plot(sol3.t, sol3.y[51], '--b', label = "Medio enológico y O_2 = 0")
axes[0,1].set_xlabel('Tiempo')
axes[0,1].set_ylabel('Concentración')
axes[0,1].set_title('Azúcares')
axes[0,1].grid(True)

#axes[1,0].plot(sol1.t, sol1.y[60], '*-b')
axes[1,0].plot(sol1.t, sol1.y[60], '-g', label="Original")
axes[1,0].plot(sol2.t, sol2.y[60], ':g', label = "Original y O_2=0")
axes[1,0].plot(sol3.t, sol3.y[60], '--g', label = "Medio enológico y O_2 = 0")
axes[1,0].set_xlabel('Tiempo')
axes[1,0].set_ylabel('Etanol')
axes[1,0].set_title('Etanol')
axes[1,0].grid(True)

# axes[1,1].plot(sol1.t, sol1.y[122], '*-g')
axes[1,1].plot(sol1.t, sol1.y[122], '-y', label="Original")
axes[1,1].plot(sol2.t, sol2.y[122], ':y', label = "Original y O_2=0")
axes[1,1].plot(sol3.t, sol3.y[122], '--y', label = "Medio enológico y O_2 = 0")
axes[1,1].set_xlabel('Tiempo')
axes[1,1].set_ylabel('Oxígeno')
axes[1,1].set_title('Oxígeno')
axes[1,1].grid(True)

fig.legend(bbox_to_anchor=(1.18, 0.8))

fig.suptitle("Modelo Yeast9 en condiciones aeróbicas")
fig.tight_layout()

# %%
model_original_o2.reactions.get_by_id("r_4046").bounds
# Out:
# (0.7, 0.7)

# %% [markdown]
# ## Modificación Yeast9 para condiciones anaeróbicas

# %%
from modificacion_yeast9 import modify_yeast9_anaerobic

# %%
model_aerobic = read_sbml_model("yeast-GEM.xml")

# %%
model_anaerobic = modify_yeast9_anaerobic(model_aerobic)
# Out:
# Removed from r_4598: ['s_3714', 's_1198', 's_1203', 's_1207', 's_1212', 's_0529']
# Not found: []

# %%
# =========================
# VERIFICACIÓN MODIFICACIONES YEAST9
# =========================

print("\n--- Verificación Biomass r_4598 ---")

rxn = model_anaerobic.reactions.get_by_id("r_4598")

mets_check = [
    "s_3714[c]",
    "s_1198[c]",
    "s_1203[c]",
    "s_1207[c]",
    "s_1212[c]",
    "s_0529[c]",
]

for mid in mets_check:
    try:
        met = model_anaerobic.metabolites.get_by_id(mid)
        coeff = rxn.metabolites.get(met, 0)
        print(f"{mid} → coeficiente en r_4598: {coeff}")
    except KeyError:
        print(f"{mid} → metabolito no existe en el modelo")

print("\n--- Verificación límites de reacciones ---")

rxn_0713 = model_anaerobic.reactions.get_by_id("r_0713")
print("r_0713 lower bound:", rxn_0713.lower_bound)

rxn_0714 = model_anaerobic.reactions.get_by_id("r_0714")
print("r_0714 lower bound:", rxn_0714.lower_bound)

rxn_0487 = model_anaerobic.reactions.get_by_id("r_0487")
print("r_0487 upper bound:", rxn_0487.upper_bound)
# Out:
# --- Verificación Biomass r_4598 ---
# s_3714[c] → metabolito no existe en el modelo
# s_1198[c] → metabolito no existe en el modelo
# s_1203[c] → metabolito no existe en el modelo
# s_1207[c] → metabolito no existe en el modelo
# s_1212[c] → metabolito no existe en el modelo
# s_0529[c] → metabolito no existe en el modelo
#
# --- Verificación límites de reacciones ---
# r_0713 lower bound: 0.0
# r_0714 lower bound: 0.0
# r_0487 upper bound: 0.0
